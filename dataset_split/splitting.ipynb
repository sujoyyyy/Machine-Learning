# %%
import pandas as pd
df= pd.read_csv('carprices.csv')
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['Mileage'],df['Sell Price($)'])

# %%
plt.scatter(df['Age(yrs)'],df['Sell Price($)'])

# %%
X = df[['Mileage','Age(yrs)']]
X
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5

# %%
y = df['Sell Price($)']
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     26750
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    18700
# 11    19500
# 12    26000
# 13    27500
# 14    19400
# 15    35000
# 16    35500
# 17    19700
# 18    12800
# 19    28200
# Name: Sell Price($), dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 13    58780         4
# 1     35000         3
# 19    52000         5
# 8     91000         8
# 0     69000         6
# 2     57000         5
# 10    83000         7
# 16    28000         2
# 3     22500         2
# 5     59000         5
# 11    79000         7
# 6     52000         5
# 18    87600         8
# 14    82450         7

# %%
X_test
# Out:
#     Mileage  Age(yrs)
# 15    25400         3
# 4     46000         4
# 17    69000         5
# 12    59000         5
# 7     72000         6
# 9     67000         6

# %%
y_train
# Out:
# 13    27500
# 1     34000
# 19    28200
# 8     12000
# 0     18000
# 2     26100
# 10    18700
# 16    35500
# 3     40000
# 5     26750
# 11    19500
# 6     32000
# 18    12800
# 14    19400
# Name: Sell Price($), dtype: int64

# %%
y_test
# Out:
# 15    35000
# 4     31500
# 17    19700
# 12    26000
# 7     19300
# 9     22000
# Name: Sell Price($), dtype: int64

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
clf.predict(X_test)
# Out:
# array([37974.76118439, 30687.42474654, 22612.58617811, 25893.84505549,
#        21100.26536445, 22740.89480314])

# %%
clf.score(X_test,y_test)
# Out:
# 0.8966081760267544

# %%
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.3,random_state=10)

# %%
X_test
# Out:
#     Mileage  Age(yrs)
# 7     72000         6
# 10    83000         7
# 5     59000         5
# 6     52000         5
# 3     22500         2
# 18    87600         8
